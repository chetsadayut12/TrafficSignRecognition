# %%
# !ls
# Out:
# app.py	sample_data  traffic_sign_model.h5

# %%
# !pip install streamlit pyngrok

# %%
from pyngrok import ngrok

ngrok.set_auth_token("36FYTx45xyg9Sgf3WsuprHvamiQ_2MBK85jymMb3WNiGHviZH")

# %%
# %%writefile app.py
import streamlit as st
import numpy as np
import tensorflow as tf
from PIL import Image

# โหลดโมเดล
model = tf.keras.models.load_model("traffic_sign_model.h5")

# =============== CLASS LABELS (GTSRB 43 CLASSES) ===============

class_names = {
    0: "Speed limit (20 km/h)",
    1: "Speed limit (30 km/h)",
    2: "Speed limit (50 km/h)",
    3: "Speed limit (60 km/h)",
    4: "Speed limit (70 km/h)",
    5: "Speed limit (80 km/h)",
    6: "End of speed limit (80 km/h)",
    7: "Speed limit (100 km/h)",
    8: "Speed limit (120 km/h)",
    9: "No passing",
    10: "No passing for vehicles over 3.5 tons",
    11: "Right-of-way at intersection",
    12: "Priority road",
    13: "Yield",
    14: "Stop",
    15: "No vehicles",
    16: "Vehicles over 3.5 tons prohibited",
    17: "No entry",
    18: "General caution",
    19: "Dangerous curve to the left",
    20: "Dangerous curve to the right",
    21: "Double curve",
    22: "Bumpy road",
    23: "Slippery road",
    24: "Road narrows on the right",
    25: "Road work",
    26: "Traffic signals",
    27: "Pedestrians",
    28: "Children crossing",
    29: "Bicycles crossing",
    30: "Beware of ice/snow",
    31: "Wild animals crossing",
    32: "End of all speed and passing limits",
    33: "Turn right ahead",
    34: "Turn left ahead",
    35: "Ahead only",
    36: "Go straight or right",
    37: "Go straight or left",
    38: "Keep right",
    39: "Keep left",
    40: "Roundabout mandatory",
    41: "End of no passing",
    42: "End of no passing for vehicles over 3.5 tons"
}

# ================================================================

st.set_page_config(page_title="Traffic Sign Recognition", layout="centered")

st.title("🚦 Traffic Sign Recognition")
st.write("อัปโหลดภาพป้ายจราจรให้โมเดลทำนาย")

uploaded_file = st.file_uploader("เลือกไฟล์ภาพ", type=["jpg", "png", "jpeg"])

if uploaded_file is not None:
    img = Image.open(uploaded_file)
    st.image(img, caption="ภาพที่อัปโหลด", width=350)

    img = img.resize((30, 30))
    img = np.expand_dims(img, axis=0)
    img = np.array(img) / 255.0

    prediction = model.predict(img)
    pred_class = np.argmax(prediction)
    label = class_names[pred_class]

    st.success(f"ผลการทำนาย: **{label}** (Class {pred_class})")
# Out:
# Overwriting app.py

# %%
from pyngrok import ngrok
public_url = ngrok.connect(8501)
public_url
# Out:
# <NgrokTunnel: "https://nonbarbarously-eightpenny-marketta.ngrok-free.dev" -> "http://localhost:8501">

# %%
# !streamlit run app.py --server.port 8501 &> /dev/null
